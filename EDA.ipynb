# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Data_cleaned.csv')
data.head()
# Out:
#   Are you still going to school?  \
# 0               No, I am at home
# 1               No, I am at home
# 2               No, I am at home
# 3               No, I am at home
# 4               No, I am at home
#
#   Do you have any other children living in your house with you?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   How many people live in your home with you (including adults)?  \
# 0                                                  4
# 1                                                  4
# 2                                                  5
# 3                                                  4
# 4                                                  5
#
#   What year are you in now? Gender  \
# 0                    Year 5    Boy
# ...

# %%
# Display summary statistics for numerical columns
numerical_summary = data.describe()
print(numerical_summary)
# Out:
#        3. How many times did you brush your teeth YESTERDAY?  \
# count                                         943.000000
# mean                                            1.626723
# std                                             0.568649
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             3.000000
#
#        13. On a scale of 0 to 10 (0 being not very safe and 10 being very safe), how safe do you feel playing in your area?  \
# count                                         943.000000
# mean                                            8.307529
# std                                             2.380658
# min                                             0.000000
# 25%                                             8.000000
# ...

# %% [markdown]
# #### 1. Distribution of hours of sleep

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up visualization style
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# Create a dictionary to store insights
eda_insights = {}

# 1. Distribution of hours of sleep
plt.figure()
sns.histplot(data['hours of sleep had last night'], bins=20, kde=True, color='blue')
plt.title("Distribution of Hours of Sleep")
plt.xlabel("Hours of Sleep")
plt.ylabel("Frequency")
plt.grid(axis='y')
eda_insights['sleep_distribution'] = "Most children had 9-11 hours of sleep, with few outliers sleeping very little or a lot."
plt.show()

# %% [markdown]
# #### 2. Relationship between brushing teeth and hours of sleep

# %%
# 2. Relationship between brushing teeth and hours of sleep
plt.figure()
sns.boxplot(x=data['3. How many times did you brush your teeth YESTERDAY?'],
            y=data['hours of sleep had last night'], palette='Set3')
plt.title("Brushing Teeth Frequency vs Hours of Sleep")
plt.xlabel("Brushing Teeth Frequency (Yesterday)")
plt.ylabel("Hours of Sleep")
eda_insights['brushing_vs_sleep'] = "Children who brushed their teeth more frequently tend to have consistent sleep hours."
plt.show()

# %% [markdown]
# #### 3. Correlation heatmap for numerical features

# %%
# 3. Correlation heatmap for numerical features
numerical_features = data.select_dtypes(include=['number'])
plt.figure()
sns.heatmap(numerical_features.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Numerical Features")
eda_insights['correlation'] = "Strong positive correlations observed between general wellbeing factors (health, school, family, friends). Sleep hours showed weak correlation with other factors."
plt.show()

# %% [markdown]
# #### 4. Boxplot for general wellbeing factors

# %%
# 4. Boxplot for general wellbeing factors
wellbeing_factors = ['Your Health ', 'Your School', 'Your Family', 'Your Friends', 
                     'Your Appearance (how you look)', 'Your Life']
plt.figure()
data[wellbeing_factors].boxplot()
plt.title("Boxplot of General Wellbeing Factors")
plt.ylabel("Score (0-10)")
eda_insights['wellbeing_boxplot'] = "Most wellbeing scores are consistently high (above 7), indicating children feel positive overall."
plt.show()

# Document insights for further analysis
eda_insights
# Out:
# {'sleep_distribution': 'Most children had 9-11 hours of sleep, with few outliers sleeping very little or a lot.',
#  'brushing_vs_sleep': 'Children who brushed their teeth more frequently tend to have consistent sleep hours.',
#  'correlation': 'Strong positive correlations observed between general wellbeing factors (health, school, family, friends). Sleep hours showed weak correlation with other factors.',
#  'wellbeing_boxplot': 'Most wellbeing scores are consistently high (above 7), indicating children feel positive overall.'}

# %% [markdown]
# #### Key Insights from Exploratory Data Analysis (EDA):

# %% [markdown]
# ##### Distribution of Hours of Sleep:
#
# * Most children slept between 9 to 11 hours, which aligns with recommended sleep for their age group.
#
# * A few outliers slept significantly less or more, indicating potential irregularities or unique cases.
#
# ##### Brushing Teeth vs. Sleep Hours:
#
# * Children who brushed their teeth more frequently tend to have more consistent and possibly healthier sleep patterns.
# There seems to be no major anomalies in brushing habits affecting sleep.
#
# ##### Correlation Analysis:
#
# * Strong positive correlations exist between general wellbeing factors (e.g., health, school, family, friends).
# Sleep hours showed a weak correlation with other factors, suggesting it is influenced by independent variables.
#
# ##### Wellbeing Scores:
#
# * Most wellbeing scores are consistently high (above 7 on a scale of 10), indicating that children generally feel positive about their health, school, family, and life.
#
# ##### Visualizations:
#
# * Histogram: Shows the distribution of hours of sleep.
#
# * Boxplot: Explores the relationship between brushing frequency and sleep hours.
#
# * Heatmap: Displays correlations between numerical features, highlighting key relationships.
#
# * Wellbeing Boxplot: Summarizes the distribution of wellbeing scores across various dimensions.

# %% [markdown]
# ####  EDA on emotional difficulty columns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select emotional difficulty columns
emotional_difficulty_columns = [
    "24. Remember, there are no right or wrong answers, just pick which is right for you. [I feel lonely]",
    "24. Remember, there are no right or wrong answers, just pick which is right for you. [I cry a lot]",
    "24. Remember, there are no right or wrong answers, just pick which is right for you. [I worry a lot]",
    "24. Remember, there are no right or wrong answers, just pick which is right for you. [I feel nobody likes me]",
    "24. Remember, there are no right or wrong answers, just pick which is right for you. [I am unhappy]"
]

# %%
# Filter data for emotional difficulty columns
emotional_difficulty_data = data[emotional_difficulty_columns]

# %%
# Define the mapping for categorical responses to numerical values
response_mapping = {
    "Never": 0,
    "Sometimes": 1,
    "Always": 2
}

# %%
# Apply the mapping to the emotional difficulty columns
for column in emotional_difficulty_columns:
    emotional_difficulty_data[column] = emotional_difficulty_data[column].map(response_mapping)
# Out:
# <ipython-input-22-244881ec4688>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emotional_difficulty_data[column] = emotional_difficulty_data[column].map(response_mapping)

# %%
# Verify if mapping worked
updated_unique_values = {column: emotional_difficulty_data[column].unique() for column in emotional_difficulty_columns}

# %%
# 1. Boxplot of Emotional Difficulty Indicators
plt.figure(figsize=(12, 6))
sns.boxplot(data=emotional_difficulty_data)
plt.title("Distribution of Emotional Difficulty Indicators (Corrected Categories)")
plt.ylabel("Scale (0 = Never, 2 = Always)")
plt.xticks(rotation=45)
plt.show()

# %%
# 2. Correlation Heatmap of Emotional Difficulty Indicators
plt.figure(figsize=(10, 8))
sns.heatmap(emotional_difficulty_data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Emotional Difficulty Indicators (Corrected Categories)")
plt.show()

# %%
# 3. Summary statistics for Emotional Difficulty Indicators
corrected_emotional_difficulty_summary = emotional_difficulty_data.describe()

# Display summary statistics
corrected_emotional_difficulty_summary
# Out:
#        24. Remember, there are no right or wrong answers, just pick which is right for you. [I feel lonely]  \
# count                                         943.000000
# mean                                            0.545069
# std                                             0.529225
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             2.000000
#
#        24. Remember, there are no right or wrong answers, just pick which is right for you. [I cry a lot]  \
# count                                         943.000000
# mean                                            0.567338
# std                                             0.534851
# min                                             0.000000
# 25%                                             0.000000
# ...

# %% [markdown]
# ### Key Insights from Emotional Difficulty Analysis

# %% [markdown]
# #### Boxplot of Emotional Difficulty Indicators:
#
# * Most children reported lower levels of emotional difficulties, leaning toward "Never" (0) or "Sometimes" (1).
# * Indicators like "I worry a lot" show higher variability and outliers, highlighting significant challenges for some children.
#
# #### Correlation Heatmap:
#
# * "I feel lonely", "I cry a lot", and "I worry a lot" are moderately correlated, suggesting these emotional difficulties often co-occur.
# * "I feel nobody likes me" and "I am unhappy" are correlated with loneliness and crying, reinforcing the interconnectedness of these struggles.
#
# #### Summary Statistics:
#
# * "I worry a lot" had the highest mean score (~0.75), indicating a common concern among children.
# * "I feel nobody likes me" had the lowest mean score (~0.35), suggesting this is less of an issue but still notable.

# %% [markdown]
# #### Recommendations for Addressing Emotional Difficulties

# %% [markdown]
# ##### Address Worrying Behavior:
#
# * Provide children with tools to manage stress and anxiety, such as mindfulness exercises or access to counseling services.
# * Create structured routines to give them a sense of stability and control.
#
# ##### Combat Loneliness:
#
# * Encourage peer interaction through safe, virtual, or physical activities (e.g., online group games, outdoor play with safety measures).
# * Strengthen family bonds through shared activities like reading, cooking, or exercising together.
#
# ##### Support Children Feeling Unhappy:
#
# * Engage children in activities that boost self-esteem, such as creative arts or sports.
# * Offer positive reinforcement to emphasize their strengths and achievements.
#
# ##### Promote Open Communication:
#
# * Create a safe environment for children to express their feelings without judgment.
# * Train teachers and parents to recognize signs of emotional distress early and respond appropriately.

# %% [markdown]
# ### Can we correlate emotional difficulties with sleep?

# %%
what are the factors influencing children's emotional difficulties

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Add the "hours of sleep had last night" column to the emotional difficulty dataset
emotional_difficulty_data['hours of sleep had last night'] = data['hours of sleep had last night']
# Out:
# <ipython-input-30-e5dfb2c13c33>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emotional_difficulty_data['hours of sleep had last night'] = data['hours of sleep had last night']

# %%
# Correlation between emotional difficulties and sleep
correlation_with_sleep = emotional_difficulty_data.corr()['hours of sleep had last night'].drop('hours of sleep had last night')

# Visualize the correlations with sleep
plt.figure(figsize=(10, 6))
correlation_with_sleep.sort_values().plot(kind='barh', color='skyblue')
plt.title("Correlation Between Emotional Difficulties and Sleep Duration")
plt.xlabel("Correlation Coefficient")
plt.ylabel("Emotional Difficulty Indicators")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #### Correlation Between Emotional Difficulties and Sleep Duration

# %% [markdown]
# ##### Insights:
#
# * Most emotional difficulties have a weak negative correlation with sleep duration, suggesting that more sleep slightly reduces emotional challenges.
#
# ##### Key Observations:
# * "I feel nobody likes me" (-0.10) and "I am unhappy" (-0.08) show the strongest (albeit weak) negative correlations with sleep.
# * "I worry a lot" shows a near-zero correlation (+0.0036), suggesting little to no direct impact of sleep on this specific difficulty.
#
# ##### Visualization:
#
# * A bar plot was created to visualize the correlation coefficients, making it easier to identify trends.

# %% [markdown]
# #### Recommendations Based on Correlation:

# %% [markdown]
# ##### Promote Adequate Sleep:
#
# * Although the correlations are weak, ensuring children get adequate sleep might help mitigate feelings of unhappiness and loneliness.
# * Encourage consistent sleep routines and minimize distractions before bedtime.
#
# ##### Address Emotional Difficulties Holistically:
#
# * Since sleep has limited impact on worrying behavior, additional interventions like stress management techniques or counseling may be needed.

# %% [markdown]
# ### EDA on behavioral difficulty columns.

# %% [markdown]
# #### Behavioral Difficulty Indicators:
# * 24. Remember, there are no right or wrong answers, just pick which is right for you. [I lose my temper]
# * 24. Remember, there are no right or wrong answers, just pick which is right for you. [I do things to hurt people]
# * 24. Remember, there are no right or wrong answers, just pick which is right for you. [I hit out when I am angry]
# * 24. Remember, there are no right or wrong answers, just pick which is right for you. [I get very angry]
# * 24. Remember, there are no right or wrong answers, just pick which is right for you. [I break things on purpose]
# * 24. Remember, there are no right or wrong answers, just pick which is right for you. [I worry when I am at school]
# * 24. Remember, there are no right or wrong answers, just pick which is right for you. [I am shy]

# %% [markdown]
# #### Additional Contextual Factors Related to Behavior:
#
# ##### Social Support:
#
# * Your Friends (Peer support and interaction)
# * Your Family (Family support and stability)
# * Sleep and Rest:
#
# * hours of sleep had last night (Sleep duration potentially affecting behavioral control)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select behavioral difficulty columns
behavioral_difficulty_columns = [
    "24. Remember, there are no right or wrong answers, just pick which is right for you. [I lose my temper]",
    "24. Remember, there are no right or wrong answers, just pick which is right for you. [I do things to hurt people]",
    "24. Remember, there are no right or wrong answers, just pick which is right for you. [I hit out when I am angry]",
    "24. Remember, there are no right or wrong answers, just pick which is right for you. [I get very angry]",
    "24. Remember, there are no right or wrong answers, just pick which is right for you. [I break things on purpose]",
    "24. Remember, there are no right or wrong answers, just pick which is right for you. [I worry when I am at school]",
    "24. Remember, there are no right or wrong answers, just pick which is right for you. [I am shy]"
]

# %%
response_mapping = {
    "Never": 0,
    "Sometimes": 1,
    "Always": 2
}

# %%
# Reload the original behavioral difficulty data
behavioral_difficulty_data = data[behavioral_difficulty_columns].copy()

# %%
# Apply the updated mapping for three categories: Never, Sometimes, Always
for column in behavioral_difficulty_columns:
    behavioral_difficulty_data[column] = behavioral_difficulty_data[column].map(response_mapping)

# %%
# Verify if mapping worked correctly
behavioral_unique_values = {column: behavioral_difficulty_data[column].unique() for column in behavioral_difficulty_columns}

# %%
# 1. Boxplot of Behavioral Difficulty Indicators
plt.figure(figsize=(12, 6))
sns.boxplot(data=behavioral_difficulty_data)
plt.title("Distribution of Behavioral Difficulty Indicators (Corrected Categories)")
plt.ylabel("Scale (0 = Never, 2 = Always)")
plt.xticks(rotation=45)
plt.show()

# %%
# 2. Correlation Heatmap of Behavioral Difficulty Indicators
plt.figure(figsize=(10, 8))
sns.heatmap(behavioral_difficulty_data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Behavioral Difficulty Indicators")
plt.show()

# %%
# 3. Summary statistics for Behavioral Difficulty Indicators
behavioral_difficulty_summary = behavioral_difficulty_data.describe()
behavioral_difficulty_summary
# Out:
#        24. Remember, there are no right or wrong answers, just pick which is right for you. [I lose my temper]  \
# count                                         943.000000
# mean                                            0.603393
# std                                             0.571500
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             2.000000
#
#        24. Remember, there are no right or wrong answers, just pick which is right for you. [I do things to hurt people]  \
# count                                         943.000000
# mean                                            0.159067
# std                                             0.399230
# min                                             0.000000
# ...

# %% [markdown]
# #### Key Insights from Behavioral Difficulty Analysis

# %% [markdown]
# ##### Boxplot of Behavioral Difficulty Indicators:
#
# * Most children reported lower levels of behavioral difficulties, leaning towards "Never" (0) or "Sometimes" (1).
# * Some indicators like "I lose my temper", "I am shy", and "I get very angry" have higher median values and show greater variability, suggesting these are common behavioral challenges.
#
# ##### Correlation Heatmap:
#
# Moderate positive correlations between:
# * "I lose my temper", "I get very angry", and "I hit out when I am angry", suggesting that these behaviors are interconnected.
# * Weak correlations with other indicators, highlighting distinct behavioral patterns.
#
#
# ##### Summary Statistics:
#
# * "I lose my temper" and "I am shy" have the highest mean scores (~0.60), indicating these are more prevalent behavioral difficulties.
# * "I break things on purpose" has the lowest mean score (~0.10), suggesting it is a relatively rare issue.
# * Standard deviations indicate moderate variability across the responses, reflecting differences in individual experiences.

# %% [markdown]
# #### Recommendations for Addressing Behavioral Difficulties

# %% [markdown]
# ##### Address Temper Issues:
#
# * Teach children anger management techniques, such as deep breathing or taking a timeout.
# Encourage open communication about emotions to reduce frustration.
# Support Shy Children:
#
# * Provide opportunities for shy children to engage in social interactions in a comfortable environment.
# Build their confidence through positive reinforcement and participation in group activities.
# Manage Aggressive Behaviors:
#
# * Address underlying triggers for aggression, such as frustration or lack of attention.
# Encourage non-violent communication and problem-solving strategies.
# Holistic Behavioral Support:
#
# *Work with parents and educators to monitor behavioral patterns and intervene early.
# Use structured routines to provide stability and reduce stress.

# %% [markdown]
# #### Analyze behavioral impact on academic performance.

# %% [markdown]
# Identify columns related to academic performance.
#
# * From the dataset, academic performance may be represented by columns such as:
# * "22. Tell us if you agree or disagree with the following: [I am doing well with my school work]"
# * "22. Tell us if you agree or disagree with the following: [I feel part of my school community]"
# * Correlate behavioral difficulty indicators with academic performance.
#
# * Provide visualizations to illustrate the relationships.
#
# * Summarize insights and actionable recommendations.

# %% [markdown]
# #### Behavioral Difficulties and Academic Performance: Key Insights

# %% [markdown]
# ##### Correlation with Academic Performance Indicators:
#
# * Behavioral difficulties show weak negative correlations with academic performance:
# * "I am doing well with my school work":
#     * Strongest negative correlations with "I hit out when I am angry" (-0.159) and "I break things on purpose" (-0.159).
# * "I feel part of my school community":
#     *Weakest negative correlations, with "I lose my temper" (-0.08) showing the strongest impact.
#
# ##### Visualizations:
#
# * The bar plot highlights the strength of negative correlations, where disruptive behaviors like anger and breaking things correlate more strongly with poorer academic performance.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Recommendations:

# %% [markdown]
# ##### Mitigate Behavioral Issues to Boost Academic Performance:
#
# * Address aggressive behaviors through anger management programs.
# * Provide structured routines to reduce frustration and emotional outbursts.
#
# ##### Enhance School Engagement:
#
# * Promote inclusive classroom activities to foster a sense of belonging for children who feel disconnected from their school community.
#
# ##### Support for Individual Challenges:
#
# * Offer personalized support and counseling for children exhibiting specific behavioral difficulties
